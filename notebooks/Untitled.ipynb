# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /Users/josh-mantovani/dsi/repos/pandas-eda-case-study/notebooks

# %%
df_CA = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/CAvideos.csv")
df_DE = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/DEvideos.csv")
df_FR = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/FRvideos.csv")
df_GB = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/GBvideos.csv")
df_IN = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/INvideos.csv")
df_JP = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/JPvideos.csv", encoding='latin-1')
df_KR = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/KRvideos.csv", encoding='latin-1')
df_MX = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/MXvideos.csv", encoding='latin-1')
df_RU = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/RUvideos.csv", encoding='latin-1')
df_US = pd.read_csv("/Users/josh-mantovani/dsi/repos/pandas-eda-case-study/data/youtube-new/USvideos.csv", encoding='latin-1')

# %%
list_of_dfs = [df_CA, df_DE, df_FR, df_GB, df_IN, df_JP, df_KR, df_MX, df_RU, df_US]

df_all = pd.concat(list_of_dfs)

# %%
df_all.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df_all.groupby('video_id').count().tail(20)
# Out:
#              trending_date  title  channel_title  category_id  publish_time  \
# video_id
# zzQsGL_F9_c              2      2              2            2             2
# zzR_hUS0mCg              2      2              2            2             2
# zzUYpmEyuMI              1      1              1            1             1
# zzUd5maVREY              3      3              3            3             3
# zzVFyVNgtsc              2      2              2            2             2
# zz_ApyWl1OQ              1      1              1            1             1
# zzbOMUm9Jm0              1      1              1            1             1
# zzcAq02ncAE              1      1              1            1             1
# zzfGVE7KO7k              1      1              1            1             1
# zzjNCiCqiOs              3      3              3            3             3
# zzo-HM-435A              1      1              1            1             1
# ...

# %%
df_all.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375942 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  375942 non-null object
# trending_date             375942 non-null object
# title                     375942 non-null object
# channel_title             375942 non-null object
# category_id               375942 non-null int64
# publish_time              375942 non-null object
# tags                      375942 non-null object
# views                     375942 non-null int64
# likes                     375942 non-null int64
# dislikes                  375942 non-null int64
# comment_count             375942 non-null int64
# thumbnail_link            375942 non-null object
# comments_disabled         375942 non-null bool
# ratings_disabled          375942 non-null bool
# video_error_or_removed    375942 non-null bool
# description               356464 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 41.2+ MB

# %%
plt.plot(df_all['trending_date'], df_all['views'])

# %%
ax.plot(df_all['trending_date'])

# %%
df_all.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375942 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  375942 non-null object
# trending_date             375942 non-null object
# title                     375942 non-null object
# channel_title             375942 non-null object
# category_id               375942 non-null int64
# publish_time              375942 non-null object
# tags                      375942 non-null object
# views                     375942 non-null int64
# likes                     375942 non-null int64
# dislikes                  375942 non-null int64
# comment_count             375942 non-null int64
# thumbnail_link            375942 non-null object
# comments_disabled         375942 non-null bool
# ratings_disabled          375942 non-null bool
# video_error_or_removed    375942 non-null bool
# description               356464 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 41.2+ MB

# %%
375942 - 356464
# Out:
# 19478

# %%
df_all['trending_date']
# Out:
# 0        17.14.11
# 1        17.14.11
# 2        17.14.11
# 3        17.14.11
# 4        17.14.11
#            ...
# 40944    18.14.06
# 40945    18.14.06
# 40946    18.14.06
# 40947    18.14.06
# 40948    18.14.06
# Name: trending_date, Length: 375942, dtype: object

# %%
df_all
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
df_all.groupby('channel_title')[['channel_title', 'trending_date']].count().sort_values('trending_date', ascending=False).head(20)
# Out:
#                                         channel_title  trending_date
# channel_title
# The Late Show with Stephen Colbert                984            984
# WWE                                               804            804
# Late Night with Seth Meyers                       773            773
# VikatanTV                                         763            763
# TheEllenShow                                      743            743
# Jimmy Kimmel Live                                 707            707
# The Tonight Show Starring Jimmy Fallon            705            705
# PewDiePie                                         652            652
# RadaanMedia                                       651            651
# The Late Late Show with James Corden              583            583
# CNN                                               579            579
# Netflix                                           566            566
# ...

# %%
df_all.groupby('title')[['trending_date']].count().sort_values('trending_date', ascending=False).head(10)
# Out:
#                                                     trending_date
# title
# Mission: Impossible - Fallout (2018) - Official...            100
# Childish Gambino - This Is America (Official Vi...             92
# Marvel Studios' Ant-Man and The Wasp - Official...             89
# Taylor Swift - Delicate                                        83
# Ed Sheeran - Happier (Official Video)                          82
# Ariana Grande - No Tears Left To Cry                           81
# Incredibles 2 - Olympics Sneak Peek                            80
# Maroon 5 - Wait                                                80
# Nicki Minaj - Chun-Li                                          78
# Incredibles 2 Official Trailer                                 78

# %%
grouped = df_US.groupby('title')[['trending_date']].count().sort_values('trending_date', ascending=False).head(10).copy()
grouped['trending_date']
# Out:
# title
# WE MADE OUR MOM CRY...HER DREAM CAME TRUE!                                               30
# Charlie Puth - BOY [Official Audio]                                                      29
# Rooster Teeth Animated Adventures - Millie So Serious                                    29
# Sam Smith - Pray (Official Video) ft. Logic                                              29
# YoungBoy Never Broke Again Goes Sneaker Shopping With Complex                            29
# The ULTIMATE $30,000 Gaming PC Setup                                                     29
# Why I'm So Scared (being myself and crying too much)                                     29
# Mission: Impossible - Fallout (2018) - Official Trailer - Paramount Pictures             29
# å¨æ°å« Jay Chouãä¸ææå°±æå If You Don't Love Me, It's FineãOfficial MV    28
# Rita Ora - Girls ft. Cardi B, Bebe Rexha & Charli XCX (Official Lyric Video)             28
# Name: trending_date, dtype: int64

# %%
titles = list(grouped.index)
# titles
views = list(grouped['trending_date'].values)
# views
titles = titles[::-1]
views = views[::-1]
titles
# Out:
# ['Rita Ora - Girls ft. Cardi B, Bebe Rexha & Charli XCX (Official Lyric Video)',
#  "å\x91¨æ\x9d°å\x80« Jay Chouã\x80\x90ä¸\x8dæ\x84\x9bæ\x88\x91å°±æ\x8b\x89å\x80\x92 If You Don't Love Me, It's Fineã\x80\x91Official MV",
#  'Mission: Impossible - Fallout (2018) - Official Trailer - Paramount Pictures',
#  "Why I'm So Scared (being myself and crying too much)",
#  'The ULTIMATE $30,000 Gaming PC Setup',
#  'YoungBoy Never Broke Again Goes Sneaker Shopping With Complex',
#  'Sam Smith - Pray (Official Video) ft. Logic',
#  'Rooster Teeth Animated Adventures - Millie So Serious',
#  'Charlie Puth - BOY [Official Audio]',
#  'WE MADE OUR MOM CRY...HER DREAM CAME TRUE!']

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.barh(titles, views)
plt.xlabel("Number of days trending")
plt.ylabel('Videos')
plt.title("Num days trending for top 10 videos")
# Out:
# Text(0.5, 1.0, 'Num days trending for top 10 videos')
# /Users/josh-mantovani/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josh-mantovani/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josh-mantovani/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josh-mantovani/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/josh-mantovani/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 141 missing from current font.
# ...

# %%
df_US[df_US['title'] == "WE MADE OUR MOM CRY...HER DREAM CAME TRUE!"]
# Out:
#           video_id trending_date                                       title  \
# 34550  j4KvrAUjn6c      18.14.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34752  j4KvrAUjn6c      18.15.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34901  j4KvrAUjn6c      18.15.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34966  j4KvrAUjn6c      18.16.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35180  j4KvrAUjn6c      18.17.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35396  j4KvrAUjn6c      18.18.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35600  j4KvrAUjn6c      18.19.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35804  j4KvrAUjn6c      18.20.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36035  j4KvrAUjn6c      18.21.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36245  j4KvrAUjn6c      18.22.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 36453  j4KvrAUjn6c      18.23.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# ...

# %%
df_RU.groupby('title')[['trending_date']].count().sort_values('trending_date', ascending=False).head(10)

# %%
#for each video how many days has it been trending

# %%
df_US.columns

# %%
plt.plot(df_US['comment_count'], df_US['views'])

# %%
# !pwd
